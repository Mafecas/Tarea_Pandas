# %% [markdown]
# <a href="https://colab.research.google.com/github/Mafecas/Tarea_Pandas/blob/main/Tarea_Pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
miBarbie=pd.read_csv("barbie_Cleaned.csv")
miBarbie.shape
miBarbie.head()
# Out:
#                                                 text rating
# 0  Beautiful film, but so preachyLoveofLegacy21 J...      6
# 1  Clever and fun beginning turns into another le...      6
# 2  It was depressingcoxaneesa24 July 2023Warning:...      8
# 3  A Technicolor Dreamheatherhilgers24 July 2023W...      9
# 4   reasons FOR seeing it and 1 reason AGAINST.im...      7
